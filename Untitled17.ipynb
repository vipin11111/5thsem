# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('dataset/placement.csv')

# %%
plt.figure(figsize=(3,4))
sns.boxplot(df['placement_exam_marks'])
plt.show()

# %%
plt.figure(figsize=(4,4))
sns.distplot(df['placement_exam_marks'])
plt.show()
# Out:
# C:\Users\91740\AppData\Local\Temp\ipykernel_18744\947313667.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['placement_exam_marks'])

# %%
df['placement_exam_marks'] = (df['placement_exam_marks'] - df['placement_exam_marks'].mean())/df['placement_exam_marks'].std()

# %%
df [(df['placement_exam_marks'] > 3 ) | (df['placement_exam_marks'] < -3)]
# Out:
#      cgpa  placement_exam_marks  placed
# 9    7.75              3.229082       1
# 134  6.33              3.176811       0
# 162  7.80              3.019996       0
# 324  6.64              3.019996       0
# 630  6.56              3.333626       1
# 730  6.14              3.019996       1
# 846  6.99              3.385897       0
# 917  5.95              3.542712       0

# %%
new_df = df[(df['placement_exam_marks'] < 3) & (df['placement_exam_marks'] > -3)]
new_df
# Out:
#      cgpa  placement_exam_marks  placed
# 0    7.19             -0.325391       1
# 1    7.46              0.301869       1
# 2    7.54              0.406412       1
# 3    6.42             -1.266281       1
# 4    7.23             -0.795836       0
# ..    ...                   ...     ...
# 995  8.87              0.615499       1
# 996  9.12              1.713204       1
# 997  4.89              0.092782       0
# 998  8.62              0.720042       1
# 999  4.90             -1.161738       1
#
# [992 rows x 3 columns]

# %%
plt.figure(figsize=(3,4))
sns.boxplot(new_df['placement_exam_marks'])
plt.show()

# %%
df['placement_exam_marks'] = (df['placement_exam_marks'] - df['placement_exam_marks'].mean())/df['placement_exam_marks'].std()

# %%
new_df.describe()
# Out:
#              cgpa  placement_exam_marks      placed
# count  992.000000            992.000000  992.000000
# mean     6.962782             -0.025936    0.489919
# std      0.615362              0.961060    0.500151
# min      4.890000             -1.684455    0.000000
# 25%      6.550000             -0.795836    0.000000
# 50%      6.960000             -0.220848    0.000000
# 75%      7.370000              0.615499    1.000000
# max      9.120000              2.863181    1.000000

# %%
df['placement_exam_marks'] = np.where
