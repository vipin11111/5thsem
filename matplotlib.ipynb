# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#creating two arrays
X=np.array([1,2,3,4,5])
Y=X**2

# %%
#plotting the values
plt.plot(X,Y)

# %%
x=np.arange(1,11)
y=x**2
z=(y/2)+40

# %%
#creating an empty canvas/figure
fig = plt.figure()

# %%
#creating an empty canvas/figure
fig = plt.figure()
#setting axes as [left, bottom, width, height]
ax = fig.add_axes([0,0,1,1])

# %%
#creating an empty canvas/figure
fig = plt.figure()
#setting axes
ax = fig.add_axes([0,0,1,1])
#plotting the lines
ax.plot(x,y,color="g",label='line1' )

# %%
#creating an empty canvas/figure
fig = plt.figure()
#setting axes
ax = fig.add_axes([0,0,1,1])
#plotting the lines
ax.plot(x,y,color="g",label='line1' )
ax.plot(x,z,color="r",label='line2')

# %%
#creating an empty canvas/figure
fig = plt.figure()
#setting axes
ax = fig.add_axes([0,0,1,1])
#plotting the lines
ax.plot(x,y,color="g", label='line1' )
ax.plot(x,z,color="r", label='line2')
ax.set_title('Title of the Plot',fontsize=15)    #setting title
ax.set_xlabel('Label for X axis',fontsize=15)    # setting X label
ax.set_ylabel('Label for Y axis',fontsize=15)    # setting Y _label
# Out:
# Text(0, 0.5, 'Label for Y axis')

# %%
#creating an empty canvas/figure
fig = plt.figure()
#setting axes
ax = fig.add_axes([0,0,1,1])
#plotting the lines
ax.plot(x,y,color="g", label='line1' )
ax.plot(x,z,color="r", label='line2')
ax.set_title('Title of the Plot',fontsize=15)    #setting title
ax.set_xlabel('Label for X axis',fontsize=15)    # setting X label
ax.set_ylabel('Label for Y axis',fontsize=15)    # setting Y _label
ax.legend()    #adding legend

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,color='r',label='line1')
ax.plot(x,z,color='b',label='line1')
ax.set_title('plot title')
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
ax.legend()
ax.legend()

# %%
#creating sample data for plotting
x = np.arange(1,16)    #1 … 15
y = x**2    #square of x values
z = (y/2)+40    #arithmetic operation applied to y values
#creating an empty canvas/figure
fig = plt.figure(figsize=(8,5))
#setting axes as [left, bottom, width, height]
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.10,0.42,0.45,0.45])
#plotting the lines
ax1.plot(x,y,color="g", label='line1' )
ax1.set_title('Title for Plot 1',fontsize=15)    #setting title
ax1.set_xlabel('Plot 1 - X axis',fontsize=15)    # setting X label
ax1.set_ylabel('Plot 1 - Y axis',fontsize=15)    # setting Y _label
ax2.plot(x,z,color="r", label='line2')
ax2.set_title('Title for Plot 2',fontsize=15)    #setting title
ax2.set_xlabel('Plot 2 - X axis',fontsize=15)    # setting X label
ax2.set_ylabel('Plot 2 - Y axis',fontsize=15)    # setting Y _label
ax1.legend()    #adding legend
ax2.legend()

# %%
#creating sample data for plotting
x = np.arange(1,16)    #1 … 15
y = x**2    #square of x values
z = (y/2)+40    #arithmetic operation applied to y values
#initializing two axes for the subplot
fig, (ax1, ax2) = plt.subplots(1, 2)    
ax1.plot(x,y,color="g", label='line1' )
ax1.set_title('Title for Plot 1',fontsize=15)    #setting title
ax1.set_xlabel('Plot 1 - X axis',fontsize=15)    # setting X label
ax1.set_ylabel('Plot 1 - Y axis',fontsize=15)    # setting Y _label
ax2.plot(x,z,color="r", label='line2')
ax2.set_title('Title for Plot 2',fontsize=15)    #setting title
ax2.set_xlabel('Plot 2 - X axis',fontsize=15)    # setting X label
ax2.set_ylabel('Plot 2 - Y axis',fontsize=15)    # setting Y _label
# Out:
# Text(0, 0.5, 'Plot 2 - Y axis')

# %%
#creating sample data for plotting
x = np.arange(1,16)    #1 … 15
y = x**2    #square of x values
z = (y/2)+40    #arithmetic operation applied to y values
#initializing two axes for the subplot
fig, (ax1, ax2) = plt.subplots(1, 2)    
ax1.plot(x,y,color="g", label='line1' )
ax1.set_title('Title for Plot 1',fontsize=15)    #setting title
ax1.set_xlabel('Plot 1 - X axis',fontsize=15)    # setting X label
ax1.set_ylabel('Plot 1 - Y axis',fontsize=15)    # setting Y _label
ax2.plot(x,z,color="r", label='line2')
ax2.set_title('Title for Plot 2',fontsize=15)    #setting title
ax2.set_xlabel('Plot 2 - X axis',fontsize=15)    # setting X label
ax2.set_ylabel('Plot 2 - Y axis',fontsize=15)    # setting Y _label
fig.tight_layout()

# %%
x=np.arange(1,11)
y=x**2
z=(y/2)+40

fig = plt.figure(figsize=(10,10))

#setting axes as [left, bottom, width, height]
ax1=fig.add_axes([0,0,0.5,0.5])
ax2=fig.add_axes([0.6,0,0.5,0.5])
ax3=fig.add_axes([0,0.6,0.5,0.5])
ax4=fig.add_axes([0.6,0.6,0.5,0.5])

ax1.plot(x,y,color='r',label='line1')
ax1.plot(x,z,color='#4B0082',label='line1')
ax1.set_title('plot title1')
ax1.set_xlabel('x-axis')
ax1.set_ylabel('y-axis')
ax1.legend()

ax2.plot(x,y,color='g',label='line1').
ax2.plot(x,z,color='y',label='line1')
ax2.set_title('plot title2')
ax2.set_xlabel('x-axis')
ax2.set_ylabel('y-axis')
ax2.legend()

ax3.plot(x,y,color='y',label='line1')
ax3.plot(x,z,color='#000000',label='line1')
ax3.set_title('plot title3')
ax3.set_xlabel('x-axis')
ax3.set_ylabel('y-axis')
ax3.legend()

ax4.plot(x,y,color='r',label='line1')
ax4.plot(x,z,color='g',label='line1')
ax4.set_title('plot title4')
ax4.set_xlabel('x-axis')
ax4.set_ylabel('y-axis')
ax4.legend()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=[10,20,30,40,50,60]
y=[1,2,3,4,5,6]
#creating an empty canvas/figure
fig = plt.figure()
#setting axes
ax = fig.add_axes([0,0,1,1])
#plotting the lines
ax.bar(x,y)
# Out:
# <BarContainer object of 6 artists>

# %%
#importing the data
import pandas as pd
df = pd.read_csv('dataset/auto_mpg.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
#replacing the null values in 'horsepower' with its mean value
df['horsepower'].fillna(df['horsepower'].mean(), inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
import matplotlib.pyplot as plt
import numpy as np
x= df['horsepower']
y= df['mpg']
#creating an empty canvas/figure
fig = plt.figure()
#setting axes
ax = fig.add_axes([0,0,1,1])
#plotting the lines
ax.scatter(x,y)

# %%
df.groupby('model_year').count()['name']
# Out:
# model_year
# 70    29
# 71    28
# 72    28
# 73    40
# 74    27
# 75    30
# 76    34
# 77    28
# 78    36
# 79    29
# 80    29
# 81    29
# 82    31
# Name: name, dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np
df_new = df.groupby('model_year').count()[['name']]
df_new.reset_index(inplace = True)
#creating an empty canvas/figure
fig = plt.figure()
#setting axes
ax = fig.add_axes([0,0,1,1])
#plotting the lines
ax.bar(df_new['model_year'],df_new['name'])
# Out:
# <BarContainer object of 13 artists>

# %%
import matplotlib.pyplot as plt
import numpy as np

#creating an empty canvas/figure
fig = plt.figure()
#setting axes
ax = fig.add_axes([0,0,1,1])
#plotting the lines
ax.hist(df['horsepower'], bins=20)
# Out:
# (array([13., 14., 55., 40., 67., 53., 40., 10.,  8., 11., 18., 29.,  7.,
#          6., 10.,  4.,  3.,  2.,  4.,  4.]),
#  array([ 46. ,  55.2,  64.4,  73.6,  82.8,  92. , 101.2, 110.4, 119.6,
#         128.8, 138. , 147.2, 156.4, 165.6, 174.8, 184. , 193.2, 202.4,
#         211.6, 220.8, 230. ]),
#  <BarContainer object of 20 artists>)

# %%
new_df = df.groupby('origin').count()[['name']]
new_df.reset_index(inplace=True)

# %%
import matplotlib.pyplot as plt
import numpy as np
new_df = df.groupby('origin').count()[['name']]
new_df.reset_index(inplace=True)
colors = ['red', 'green', 'blue' ]
explode = [0.05, 0, 0]
#creating an empty canvas/figure
fig = plt.figure()
#setting axes
ax = fig.add_axes([0,0,1,1])
#plotting the lines
ax.pie(new_df['name'], labels=new_df['origin'], colors = colors, explode = explode, autopct='%0.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1809e2e7ad0>,
#   <matplotlib.patches.Wedge at 0x1809e051850>,
#   <matplotlib.patches.Wedge at 0x1809e053090>],
#  [Text(0.9788723988472815, 0.6035800085945263, 'europe'),
#   Text(-0.1729355121735563, 1.0863209970488787, 'japan'),
#   Text(-0.4229564276124259, -1.0154348134377384, 'usa')],
#  [Text(0.5532757036962895, 0.34115391790125404, '17.6%'),
#   Text(-0.09432846118557615, 0.5925387256630247, '19.8%'),
#   Text(-0.2307035059704141, -0.5538735346024027, '62.6%')])

# %%
import seaborn as sns

sns.scatterplot(x='horsepower', y='mpg', hue='origin', style='cylinders',data=df)
# Out:
# <Axes: xlabel='horsepower', ylabel='mpg'>

# %%
import pandas as pd
df=pd.read_csv('dataset/auto_mpg.csv')
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
import matplotlib.pyplot as plt
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.set_title('distribution of miliage')
ax.boxplot(df['mpg'])
fig.show()
# Out:
# C:\Users\bldea\AppData\Local\Temp\ipykernel_3372\2653740233.py:6: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
#adding new row of city_mpg to df
df['city_mpg']=df[['mpg']]*0.75
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name  city_milage  city_mileage  \
# 0            70     usa  chevrolet chevelle malibu        13.50         13.50
# 1            70     usa          buick skylark 320        11.25         11.25
# 2            70     usa         plymouth satellite        13.50         13.50
# 3            70     usa              amc rebel sst        12.00         12.00
# 4            70     usa                ford torino        12.75         12.75
# ..          ...     ...                        ...          ...           ...
# 393          82     usa            ford mustang gl        20.25         20.25
# 394          82  europe                  vw pickup        33.00         33.00
# 395          82     usa              dodge rampage        24.00         24.00
# 396          82     usa                ford ranger        21.00         21.00
# 397          82     usa                 chevy s-10        23.25         23.25
#
#      city_mpg
# 0       13.50
# 1       11.25
# 2       13.50
# 3       12.00
# 4       12.75
# ..        ...
# 393     20.25
# 394     33.00
# 395     24.00
# 396     21.00
# 397     23.25
#
# [398 rows x 12 columns]

# %%
import matplotlib.pyplot as plt
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.set_title('disturubation of average mpg vs city_mpg')
ax.set_ylabel('milage per gallon')
ax.set_xlabel('mpg                                                              city_mpg')
ax.boxplot([df['mpg'],df['city_mpg']])
fig.show()
# Out:
# C:\Users\bldea\AppData\Local\Temp\ipykernel_3372\3296415821.py:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
line_df=df.groupby(by=['model_year'])
line_df = line_df.mean() #creating a sub dataframe for the line graph
# Out:
# C:\Users\bldea\AppData\Local\Temp\ipykernel_3372\4144906971.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   line_df = line_df.mean() #creating a sub dataframe for the line graph

# %%
#importing the required packages
import matplotlib.pyplot as plt
#creating an empty canvas/figure
fig = plt.figure(figsize=[8,4])
#setting axes
ax = fig.add_axes([0, 0, 1, 1])
#plotting the lines
ax.plot(line_df['mpg']/10,label='Mileage /10')
ax.plot(line_df['weight']/1000,label='Weight /1000')
ax.plot(line_df['horsepower']/100,label='Horsepower /100')
ax.set_title('Mileage vs Weight vs Horsepower',fontsize = 17)
ax.set_ylabel('Value',fontsize=12)
ax.set_xlabel('Model year',fontsize=12)
ax.legend()
fig.show()
# Out:
# C:\Users\bldea\AppData\Local\Temp\ipykernel_3372\3765946225.py:15: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
#importing the required packages
import matplotlib.pyplot as plt
#creating an empty canvas/figure
fig = plt.figure(figsize=[8,4])
#setting axes
ax = fig.add_axes([0, 0, 1, 1])
#plotting the lines
ax.plot(line_df['mpg']/10,label='Mileage', linestyle='-',linewidth=2)
ax.plot(line_df['weight']/1000,label='Weight',linestyle=':',linewidth=3)
ax.plot(line_df['horsepower']/100,label='Horsepower',linestyle='--',linewidth=3)
# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’
ax.set_title('Mileage vs Weight vs Horsepower',fontsize = 17)
ax.set_ylabel('Value',fontsize=12)
ax.set_xlabel('Model year',fontsize=12)
ax.legend()
fig.show()
# Out:
# C:\Users\bldea\AppData\Local\Temp\ipykernel_3372\502883018.py:16: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
#importing the required packages
import matplotlib.pyplot as plt
#creating an empty canvas/figure
fig = plt.figure(figsize=[10,5])
#setting axes
ax = fig.add_axes([0, 0, 1, 1])
#plotting the lines
ax.plot(line_df['mpg']/10,label='Mileage')
ax.plot(line_df['weight']/1000,label='Weight')
ax.plot(line_df['horsepower']/100,label='Horsepower')
plt.text(75.5, 1.14, 'Horsepower',
             va = 'center', #va -> vertical alignment
             rotation = 4, #angle
             bbox = dict( 
                     boxstyle = 'round',
                     facecolor = 'wheat',
                     alpha = 0.3)) #background style
plt.text(75.5, 2.25, 'Mileage',va = 'center',rotation = 17,bbox = dict(boxstyle = 'round',facecolor = 'wheat',alpha = 0.3))
plt.text(76, 3.15, 'Weight',va = 'center',rotation = -13,bbox = dict(boxstyle = 'round',facecolor = 'wheat',alpha = 0.3))
plt.annotate('Highest Mileage', xy=(80.1, 3.39), xytext=(80.5, 3.38), arrowprops=dict(facecolor='wheat', shrink=.01))
plt.annotate('Lowest Mileage', xy=(73.05, 1.70), xytext=(73.5, 1.69), arrowprops=dict(facecolor='wheat', shrink=.01))
ax.set_title('Mileage vs Weight vs Horsepower',fontsize = 17)
ax.set_ylabel('Value',fontsize=12)
ax.set_xlabel('Model year',fontsize=12)
fig.show()
# Out:
# C:\Users\bldea\AppData\Local\Temp\ipykernel_3372\4102938735.py:25: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
#importing the required packages
import matplotlib.pyplot as plt
#creating an empty canvas/figure
fig = plt.figure(figsize=[8,4])
#setting axes
ax = fig.add_axes([0, 0, 1, 1])
#plotting the lines
ax.plot(line_df['mpg']/10,label='Mileage', color="g", marker='+', markersize = 7)
ax.plot(line_df['weight']/1000,label='Weight', color="b", marker='o', markersize = 7)
ax.plot(line_df['horsepower']/100,label='Horsepower', color="r", marker='s', markersize = 7)
# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.set_title('Mileage vs Weight vs Horsepower',fontsize = 17)
ax.set_ylabel('Value',fontsize=12)
ax.set_xlabel('Model year',fontsize=12)
ax.legend()
fig.show()
# Out:
# C:\Users\bldea\AppData\Local\Temp\ipykernel_3372\3245933419.py:16: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
