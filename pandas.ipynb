# %%
import numpy as np
import pandas as pd

# %%
series = pd.Series(data = [78, 92, 36, 64, 89],index=[1,2,3,4,5])  
series
# Out:
# 1    78
# 2    92
# 3    36
# 4    64
# 5    89
# dtype: int64

# %%
series.values
# Out:
# array([78, 92, 36, 64, 89], dtype=int64)

# %%
series.index
# Out:
# Int64Index([1, 2, 3, 4, 5], dtype='int64')

# %%
series[1]
# Out:
# 92

# %%
series[1:3]
# Out:
# 1    92
# 2    36
# dtype: int64

# %%
data = pd.Series(data = [700000, 800000, 1600000, 1800000, 30000000], index = ['Swift', 'Jazz', 'Civic', 'Altis', 'Gallardo'])
data
# Out:
# Swift         700000
# Jazz          800000
# Civic        1600000
# Altis        1800000
# Gallardo    30000000
# dtype: int64

# %%
data['Swift']
# Out:
# 700000

# %%
data['Jazz': 'Gallardo']
# Out:
# Jazz          800000
# Civic        1600000
# Altis        1800000
# Gallardo    30000000
# dtype: int64

# %%
 
car_price_dict = {'Swift':  700000,
                       'Jazz' :  800000,
                       'Civic' : 1600000,
                       'Altis' : 1800000,
                       'Gallardo': 30000000
                      }
car_price = pd.Series(car_price_dict)
car_price
# Out:
# Swift         700000
# Jazz          800000
# Civic        1600000
# Altis        1800000
# Gallardo    30000000
# dtype: int64

# %%
car_price_dict = {'Swift':  700000,
                       'Jazz' :  800000,
                       'Civic' : 1600000,
                       'Altis' : 1800000,
                       'Gallardo': 30000000
                      }
car_price = pd.Series(car_price_dict)

car_man_dict = {'Swift' : 'Maruti',
                  'Jazz'   : 'Honda',
                  'Civic'  : 'Honda',
                  'Altis'  : 'Toyota',
                   'Gallardo' : 'Lamborghini'}
car_man = pd.Series(car_man_dict)
print(car_price)
print(car_man)
# Out:
# Swift         700000
# Jazz          800000
# Civic        1600000
# Altis        1800000
# Gallardo    30000000
# dtype: int64
# Swift            Maruti
# Jazz              Honda
# Civic             Honda
# Altis            Toyota
# Gallardo    Lamborghini
# dtype: object

# %%
cars = pd.DataFrame({'Price': car_price , 'Manufacturer' : car_man})
cars
# Out:
#              Price Manufacturer
# Swift       700000       Maruti
# Jazz        800000        Honda
# Civic      1600000        Honda
# Altis      1800000       Toyota
# Gallardo  30000000  Lamborghini

# %%
cars['Price']
# Out:
# Swift         700000
# Jazz          800000
# Civic        1600000
# Altis        1800000
# Gallardo    30000000
# Name: Price, dtype: int64

# %%
cars['Manufacturer']
# Out:
# Swift            Maruti
# Jazz              Honda
# Civic             Honda
# Altis            Toyota
# Gallardo    Lamborghini
# Name: Manufacturer, dtype: object

# %%
car_price_dict = {'Swift':  700000,
                       'Jazz' :  800000,
                       'Civic' : 1600000,
                       'Altis' : 1800000,
                       'Gallardo': 30000000
                      }
car_price = pd.Series(car_price_dict)
car_price
pd.DataFrame(car_price, columns=['Car Price'])
# Out:
#           Car Price
# Swift        700000
# Jazz         800000
# Civic       1600000
# Altis       1800000
# Gallardo   30000000

# %%
data = [{'Name': 'Subodh', 'Marks': 28},
        {'Name': 'Ram', 'Marks': 27}, 
        {'Name': 'Abdul', 'Marks': 26}, 
        {'Name': 'John', 'Marks': 28}]
pd.DataFrame(data)
# Out:
#      Name  Marks
# 0  Subodh     28
# 1     Ram     27
# 2   Abdul     26
# 3    John     28

# %%
data_json=pd.read_json('relaxed.json')
data_json
# Out:
#    id   type           name   ppu  \
# 0   1  donut           Cake  0.55
# 1   2  donut         Raised  0.55
# 2   3  donut  Old Fashioned  0.55
#
#                                              batters  \
# 0  {'batter': [{'id': '1001', 'type': 'Regular'},...
# 1    {'batter': [{'id': '1001', 'type': 'Regular'}]}
# 2  {'batter': [{'id': '1001', 'type': 'Regular'},...
#
#                                              topping
# 0  [{'id': '5001', 'type': 'None'}, {'id': '5002'...
# 1  [{'id': '5001', 'type': 'None'}, {'id': '5002'...
# 2  [{'id': '5001', 'type': 'None'}, {'id': '5002'...

# %%
import pandas as pd
df = pd.read_csv('dataset/auto-mpg1.csv')
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0     NaN          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0          70.0       1  chevrolet chevelle malibu
# 1          70.0       1          buick skylark 320
# 2           NaN       1         plymouth satellite
# 3          70.0       1              amc rebel sst
# 4          70.0       1                ford torino
# ..          ...     ...                        ...
# 393        82.0       1            ford mustang gl
# 394        82.0       2                  vw pickup
# 395        82.0       1              dodge rampage
# 396        82.0       1                ford ranger
# 397        82.0       1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0   NaN          8         307.0        130    3504          12.0        70.0
# 1  15.0          8         350.0        165    3693          11.5        70.0
# 2  18.0          8         318.0        150    3436          11.0         NaN
# 3  16.0          8         304.0        150    3433          12.0        70.0
# 4  17.0          8         302.0        140    3449          10.5        70.0
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.tail()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin             name
# 393        82.0       1  ford mustang gl
# 394        82.0       2        vw pickup
# 395        82.0       1    dodge rampage
# 396        82.0       1      ford ranger
# 397        82.0       1       chevy s-10

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  396.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.550000    5.454774    193.425879  2970.424623     15.568090
# std      7.819024    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model_year      origin
# count  396.000000  398.000000
# mean    76.040404    1.572864
# std      3.682100    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           396 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    396 non-null    float64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
df.dropna(inplace = True)
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 1    15.0          8         350.0        165    3693          11.5
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# 6    14.0          8         454.0        220    4354           9.0
# 7    14.0          8         440.0        215    4312           8.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin               name
# 1          70.0       1  buick skylark 320
# 3          70.0       1      amc rebel sst
# 4          70.0       1        ford torino
# 6          70.0       1   chevrolet impala
# 7          70.0       1  plymouth fury iii
# ..          ...     ...                ...
# 393        82.0       1    ford mustang gl
# 394        82.0       2          vw pickup
# 395        82.0       1      dodge rampage
# 396        82.0       1        ford ranger
# 397        82.0       1         chevy s-10
#
# [395 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 395 entries, 1 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           395 non-null    float64
#  1   cylinders     395 non-null    int64
#  2   displacement  395 non-null    float64
#  3   horsepower    395 non-null    object
#  4   weight        395 non-null    int64
#  5   acceleration  395 non-null    float64
#  6   model_year    395 non-null    float64
#  7   origin        395 non-null    int64
#  8   name          395 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 30.9+ KB

# %%
df['mpg']
# Out:
# 1      15.0
# 3      16.0
# 4      17.0
# 6      14.0
# 7      14.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 395, dtype: float64

# %%
df[['mpg']]
# Out:
#       mpg
# 1    15.0
# 3    16.0
# 4    17.0
# 6    14.0
# 7    14.0
# ..    ...
# 393  27.0
# 394  44.0
# 395  32.0
# 396  28.0
# 397  31.0
#
# [395 rows x 1 columns]

# %%
df[['mpg','weight','model_year']]
# Out:
#       mpg  weight  model_year
# 1    15.0    3693        70.0
# 3    16.0    3433        70.0
# 4    17.0    3449        70.0
# 6    14.0    4354        70.0
# 7    14.0    4312        70.0
# ..    ...     ...         ...
# 393  27.0    2790        82.0
# 394  44.0    2130        82.0
# 395  32.0    2295        82.0
# 396  28.0    2625        82.0
# 397  31.0    2720        82.0
#
# [395 rows x 3 columns]

# %%
df.fillna(23.5,inplace=True)

# %%
df.iloc[0:5,3:6]
# Out:
#   horsepower  weight  acceleration
# 0        130    3504          12.0
# 1        165    3693          11.5
# 2        150    3436          11.0
# 3        150    3433          12.0
# 4        140    3449          10.5

# %%
df.loc[0:5,'horsepower':'model_year']
# Out:
#   horsepower  weight  acceleration  model_year
# 0        130    3504          12.0        70.0
# 1        165    3693          11.5        70.0
# 2        150    3436          11.0         NaN
# 3        150    3433          12.0        70.0
# 4        140    3449          10.5        70.0
# 5        198    4341          10.0         NaN

# %%
df_name=df.head()
df_name
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0   NaN          8         307.0        130    3504          12.0        70.0
# 1  15.0          8         350.0        165    3693          11.5        70.0
# 2  18.0          8         318.0        150    3436          11.0         NaN
# 3  16.0          8         304.0        150    3433          12.0        70.0
# 4  17.0          8         302.0        140    3449          10.5        70.0
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df_name.set_index('name', inplace = True)
df_name
# Out:
#                             mpg  cylinders  displacement horsepower  weight  \
# name
# chevrolet chevelle malibu   NaN          8         307.0        130    3504
# buick skylark 320          15.0          8         350.0        165    3693
# plymouth satellite         18.0          8         318.0        150    3436
# amc rebel sst              16.0          8         304.0        150    3433
# ford torino                17.0          8         302.0        140    3449
#
#                            acceleration  model_year  origin
# name
# chevrolet chevelle malibu          12.0        70.0       1
# buick skylark 320                  11.5        70.0       1
# plymouth satellite                 11.0         NaN       1
# amc rebel sst                      12.0        70.0       1
# ford torino                        10.5        70.0       1

# %%
df.iloc[5:10,4:7]
# Out:
#                     weight  acceleration  model_year
# name
# ford galaxie 500      4341          10.0         NaN
# chevrolet impala      4354           9.0        70.0
# plymouth fury iii     4312           8.5        70.0
# pontiac catalina      4425          10.0        70.0
# amc ambassador dpl    3850           8.5        70.0

# %%
df.head(10)
# Out:
#                             mpg  cylinders  displacement horsepower  weight  \
# name
# chevrolet chevelle malibu   NaN          8         307.0        130    3504
# buick skylark 320          15.0          8         350.0        165    3693
# plymouth satellite         18.0          8         318.0        150    3436
# amc rebel sst              16.0          8         304.0        150    3433
# ford torino                17.0          8         302.0        140    3449
# ford galaxie 500            NaN          8         429.0        198    4341
# chevrolet impala           14.0          8         454.0        220    4354
# plymouth fury iii          14.0          8         440.0        215    4312
# pontiac catalina           14.0          8         455.0        225    4425
# amc ambassador dpl         15.0          8         390.0        190    3850
#
#                            acceleration  model_year  origin
# name
# chevrolet chevelle malibu          12.0        70.0       1
# buick skylark 320                  11.5        70.0       1
# plymouth satellite                 11.0         NaN       1
# amc rebel sst                      12.0        70.0       1
# ford torino                        10.5        70.0       1
# ford galaxie 500                   10.0         NaN       1
# chevrolet impala                    9.0        70.0       1
# plymouth fury iii                   8.5        70.0       1
# pontiac catalina                   10.0        70.0       1
# amc ambassador dpl                  8.5        70.0       1

# %%
df.loc[0:5, ['cylinders', 'horsepower', 'name']]
# Out:
#    cylinders horsepower                       name
# 0          8        130  chevrolet chevelle malibu
# 1          8        165          buick skylark 320
# 2          8        150         plymouth satellite
# 3          8        150              amc rebel sst
# 4          8        140                ford torino
# 5          8        198           ford galaxie 500

# %%
marks = {'Chemistry': [67,90,66,32], 
        'Physics': [45,92,72,40],  
        'Mathematics': [50,87,81,12],  
        'English': [19,90,72,68]}
marks_df = pd.DataFrame(marks, index = ['Subodh', 'Ram', 'Abdul', 'John'])
marks_df
# Out:
#         Chemistry  Physics  Mathematics  English
# Subodh         67       45           50       19
# Ram            90       92           87       90
# Abdul          66       72           81       72
# John           32       40           12       68

# %%
marks_df['Total'] = marks_df['Chemistry'] + marks_df['Physics'] + marks_df['Mathematics'] + marks_df['English']
marks_df
# Out:
#         Chemistry  Physics  Mathematics  English  Total
# Subodh         67       45           50       19    181
# Ram            90       92           87       90    359
# Abdul          66       72           81       72    291
# John           32       40           12       68    152

# %%
marks_df.drop(columns = 'Total', inplace = True)

# %%
marks_df
# Out:
#         Chemistry  Physics  Mathematics  English
# Subodh         67       45           50       19
# Ram            90       92           87       90
# Abdul          66       72           81       72
# John           32       40           12       68

# %%
import pandas as pd
df = pd.read_csv('dataset/auto-mpg.csv')
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# 1            70       1          buick skylark 320
# 2            70       1         plymouth satellite
# 3            70       1              amc rebel sst
# 4            70       1                ford torino
# ..          ...     ...                        ...
# 393          82       1            ford mustang gl
# 394          82       2                  vw pickup
# 395          82       1              dodge rampage
# 396          82       1                ford ranger
# 397          82       1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df.loc[df['model_year'] == 72]
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  \
# 57  24.0          4         113.0         95    2278          15.5
# 58  25.0          4          97.5         80    2126          17.0
# 59  23.0          4          97.0         54    2254          23.5
# 60  20.0          4         140.0         90    2408          19.5
# 61  21.0          4         122.0         86    2226          16.5
# 62  13.0          8         350.0        165    4274          12.0
# 63  14.0          8         400.0        175    4385          12.0
# 64  15.0          8         318.0        150    4135          13.5
# 65  14.0          8         351.0        153    4129          13.0
# 66  17.0          8         304.0        150    3672          11.5
# 67  11.0          8         429.0        208    4633          11.0
# 68  13.0          8         350.0        155    4502          13.5
# 69  12.0          8         350.0        160    4456          13.5
# 70  13.0          8         400.0        190    4422          12.5
# 71  19.0          3          70.0         97    2330          13.5
# 72  15.0          8         304.0        150    3892          12.5
# 73  13.0          8         307.0        130    4098          14.0
# 74  13.0          8         302.0        140    4294          16.0
# 75  14.0          8         318.0        150    4077          14.0
# 76  18.0          4         121.0        112    2933          14.5
# 77  22.0          4         121.0         76    2511          18.0
# 78  21.0          4         120.0         87    2979          19.5
# 79  26.0          4          96.0         69    2189          18.0
# 80  22.0          4         122.0         86    2395          16.0
# 81  28.0          4          97.0         92    2288          17.0
# 82  23.0          4         120.0         97    2506          14.5
# 83  28.0          4          98.0         80    2164          15.0
# 84  27.0          4          97.0         88    2100          16.5
#
#     model_year  origin                              name
# 57          72       3             toyota corona hardtop
# 58          72       1                dodge colt hardtop
# 59          72       2                 volkswagen type 3
# 60          72       1                    chevrolet vega
# 61          72       1               ford pinto runabout
# 62          72       1                  chevrolet impala
# 63          72       1                  pontiac catalina
# 64          72       1                 plymouth fury iii
# 65          72       1                  ford galaxie 500
# 66          72       1                amc ambassador sst
# 67          72       1                   mercury marquis
# 68          72       1              buick lesabre custom
# 69          72       1        oldsmobile delta 88 royale
# 70          72       1            chrysler newport royal
# 71          72       3                   mazda rx2 coupe
# 72          72       1                  amc matador (sw)
# 73          72       1  chevrolet chevelle concours (sw)
# 74          72       1             ford gran torino (sw)
# 75          72       1    plymouth satellite custom (sw)
# 76          72       2                   volvo 145e (sw)
# 77          72       2               volkswagen 411 (sw)
# 78          72       2                  peugeot 504 (sw)
# 79          72       2                   renault 12 (sw)
# 80          72       1                   ford pinto (sw)
# 81          72       3                   datsun 510 (sw)
# 82          72       3       toyouta corona mark ii (sw)
# 83          72       1                   dodge colt (sw)
# 84          72       3          toyota corolla 1600 (sw)

# %%
df.loc[(df['origin'] == 3)&(df['cylinders']==6)]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 123  20.0          6         156.0        122    2807          13.5
# 210  19.0          6         156.0        108    2930          15.5
# 241  22.0          6         146.0         97    2815          14.5
# 333  32.7          6         168.0        132    2910          11.4
# 361  25.4          6         168.0        116    2900          12.6
# 362  24.2          6         146.0        120    2930          13.8
#
#      model_year  origin               name
# 123          73       3     toyota mark ii
# 210          76       3     toyota mark ii
# 241          77       3         datsun 810
# 333          80       3      datsun 280-zx
# 361          81       3    toyota cressida
# 362          81       3  datsun 810 maxima

# %%
#to change dtype of horse object to float
df['horsepower']=pd.to_numeric(df['horsepower'],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(4), int64(4), object(1)
# memory usage: 28.1+ KB

# %%
# Fuel efficient
# MPG > 29, Horsepower < 93.5,
# Weight < 2500
df.loc[(df['mpg'] > 29) & (df['horsepower'] < 93.5) & (df['weight'] < 2500)]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 51   30.0          4          79.0        70.0    2074          19.5
# 52   30.0          4          88.0        76.0    2065          14.5
# 53   31.0          4          71.0        65.0    1773          19.0
# 54   35.0          4          72.0        69.0    1613          18.0
# 129  31.0          4          79.0        67.0    1950          19.0
# ..    ...        ...           ...         ...     ...           ...
# 384  32.0          4          91.0        67.0    1965          15.7
# 385  38.0          4          91.0        67.0    1995          16.2
# 391  36.0          4         135.0        84.0    2370          13.0
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
#
#      model_year  origin                 name
# 51           71       2          peugeot 304
# 52           71       2            fiat 124b
# 53           71       3  toyota corolla 1200
# 54           71       3          datsun 1200
# 129          74       3          datsun b210
# ..          ...     ...                  ...
# 384          82       3   honda civic (auto)
# 385          82       3        datsun 310 gx
# 391          82       1    dodge charger 2.2
# 394          82       2            vw pickup
# 395          82       1        dodge rampage
#
# [81 rows x 9 columns]

# %%
# Muscle cars
# Displacement >262, Horsepower > 126, Weight in range[2800, 3600]
df.loc[(df['displacement'] > 262) & (df['horsepower'] > 126) & (df['weight'] >=2800) & (df['weight'] <= 3600)]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# 198          76       3                      honda civic
# 216          77       3                honda accord cvcc
# 218          77       2                    renault 5 gtl
# 244          78       2  volkswagen rabbit custom diesel
# 246          78       3                 mazda glc deluxe
# 247          78       3                   datsun b210 gx
# 303          79       3                       datsun 210
# 310          80       3            toyota corolla tercel
# 322          80       3                        mazda glc
# 324          80       3                       datsun 210
# 325          80       2             vw rabbit c (diesel)
# 330          80       2             renault lecar deluxe
# 331          80       3                        subaru dl
# 346          81       3                           subaru
# 347          81       3                   datsun 210 mpg
# 348          81       3                    toyota tercel
# 376          82       3               mazda glc custom l
# 377          82       3                 mazda glc custom
# 379          82       1                   mercury lynx l
# 394          82       2                        vw pickup

# %%
marks = [{'Chemistry': 67, 'Physics': 45, 'Mathematics': 50, 'English' : 19},
        {'Chemistry': 90, 'Physics': 92, 'Mathematics': 87, 'English' : 90}, 
        {'Chemistry': 66, 'Physics': 72, 'Mathematics': 81, 'English' : 72}, 
        {'Chemistry': 32, 'Physics': 40, 'Mathematics': 12, 'English' : 68}]
marks_df = pd.DataFrame(marks, index = ['Subodh', 'Ram', 'Abdul', 'John'])
marks_df
# Out:
#         Chemistry  Physics  Mathematics  English
# Subodh         67       45           50       19
# Ram            90       92           87       90
# Abdul          66       72           81       72
# John           32       40           12       68

# %%
marks_df.mask(marks_df < 33, 'Fail')
# Out:
#        Chemistry  Physics Mathematics English
# Subodh        67       45          50    Fail
# Ram           90       92          87      90
# Abdul         66       72          81      72
# John        Fail       40        Fail      68

# %%
df.sort_values(by = 'cylinders')
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 111  18.0          3          70.0        90.0    2124          13.5
# 71   19.0          3          70.0        97.0    2330          13.5
# 334  23.7          3          70.0       100.0    2420          12.5
# 243  21.5          3          80.0       110.0    2720          13.5
# 267  27.5          4         134.0        95.0    2560          14.2
# ..    ...        ...           ...         ...     ...           ...
# 86   14.0          8         304.0       150.0    3672          11.5
# 285  17.0          8         305.0       130.0    3840          15.4
# 286  17.6          8         302.0       129.0    3725          13.4
# 92   13.0          8         351.0       158.0    4363          13.0
# 0    18.0          8         307.0       130.0    3504          12.0
#
#      model_year  origin                       name
# 111          73       3                  maxda rx3
# 71           72       3            mazda rx2 coupe
# 334          80       3              mazda rx-7 gs
# 243          77       3                 mazda rx-4
# 267          78       3              toyota corona
# ..          ...     ...                        ...
# 86           73       1                amc matador
# 285          79       1  chevrolet caprice classic
# 286          79       1            ford ltd landau
# 92           73       1                   ford ltd
# 0            70       1  chevrolet chevelle malibu
#
# [398 rows x 9 columns]

# %%
df.sort_values(['acceleration', 'mpg','cylinders'], ascending = (1,0,1))
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 11   14.0          8         340.0       160.0    3609           8.0
# 9    15.0          8         390.0       190.0    3850           8.5
# 7    14.0          8         440.0       215.0    4312           8.5
# 6    14.0          8         454.0       220.0    4354           9.0
# 116  16.0          8         400.0       230.0    4278           9.5
# ..    ...        ...           ...         ...     ...           ...
# 300  23.9          8         260.0        90.0    3420          22.2
# 59   23.0          4          97.0        54.0    2254          23.5
# 326  43.4          4          90.0        48.0    2335          23.7
# 394  44.0          4          97.0        52.0    2130          24.6
# 299  27.2          4         141.0        71.0    3190          24.8
#
#      model_year  origin                               name
# 11           70       1                 plymouth 'cuda 340
# 9            70       1                 amc ambassador dpl
# 7            70       1                  plymouth fury iii
# 6            70       1                   chevrolet impala
# 116          73       1                 pontiac grand prix
# ..          ...     ...                                ...
# 300          79       1  oldsmobile cutlass salon brougham
# 59           72       2                  volkswagen type 3
# 326          80       2                 vw dasher (diesel)
# 394          82       2                          vw pickup
# 299          79       2                        peugeot 504
#
# [398 rows x 9 columns]

# %%
import pandas as pd
import numpy as np
marks = {'Chemistry': [67,90,66,32], 
        'Physics': [45,92,72,40],  
        'Mathematics': [50,87,81,12],  
        'English': [19,90,72,68]}
marks_df = pd.DataFrame(marks, index = ['Subodh', 'Ram', 'Abdul', 'John'])
marks_df
# Out:
#         Chemistry  Physics  Mathematics  English
# Subodh         67       45           50       19
# Ram            90       92           87       90
# Abdul          66       72           81       72
# John           32       40           12       68

# %%
#encrypting marks as sine of marks
encrypted_marks = np.sin(marks_df)
encrypted_marks
# Out:
#         Chemistry   Physics  Mathematics   English
# Subodh  -0.855520  0.850904    -0.262375  0.149877
# Ram      0.893997 -0.779466    -0.821818  0.893997
# Abdul   -0.026551  0.253823    -0.629888  0.253823
# John     0.551427  0.745113    -0.536573 -0.897928

# %%
encrypted_marks.reset_index(inplace = True)
encrypted_marks
# Out:
#     index  Chemistry   Physics  Mathematics   English
# 0  Subodh  -0.855520  0.850904    -0.262375  0.149877
# 1     Ram   0.893997 -0.779466    -0.821818  0.893997
# 2   Abdul  -0.026551  0.253823    -0.629888  0.253823
# 3    John   0.551427  0.745113    -0.536573 -0.897928

# %%
new_marks = marks_df + 5
new_marks
# Out:
#         Chemistry  Physics  Mathematics  English
# Subodh         72       50           55       24
# Ram            95       97           92       95
# Abdul          71       77           86       77
# John           37       45           17       73

# %%
new_marks = marks_df + [5,10,10,2]
new_marks
# Out:
#         Chemistry  Physics  Mathematics  English
# Subodh         72       55           60       21
# Ram            95      102           97       92
# Abdul          71       82           91       74
# John           37       50           22       70

# %%
#Creating the DataFrame
marks = {'Chemistry': [67,90,66,32], 
        'Physics': [45,92,72,40],  
        'Mathematics': [50,87,81,12],  
        'English': [19,90,72,68]}
marks_df = pd.DataFrame(marks, index = ['James', 'Lee', 'Anderson', 'John'])
marks_df
# Out:
#           Chemistry  Physics  Mathematics  English
# James            67       45           50       19
# Lee              90       92           87       90
# Anderson         66       72           81       72
# John             32       40           12       68

# %%
marks_df.apply(np.sum, axis = 0)
# Out:
# Chemistry      255
# Physics        249
# Mathematics    230
# English        249
# dtype: int64

# %%
marks_df.apply(np.sum, axis = 1)
# Out:
# James       181
# Lee         359
# Anderson    291
# John        152
# dtype: int64

# %%
marks_df.apply(func = np.mean, axis = 0, result_type = 'broadcast')
# Out:
#           Chemistry  Physics  Mathematics  English
# James            63       62           57       62
# Lee              63       62           57       62
# Anderson         63       62           57       62
# John             63       62           57       62

# %%
import pandas as pd
df = pd.read_csv('dataset/auto-mpg.csv')
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# 1            70       1          buick skylark 320
# 2            70       1         plymouth satellite
# 3            70       1              amc rebel sst
# 4            70       1                ford torino
# ..          ...     ...                        ...
# 393          82       1            ford mustang gl
# 394          82       2                  vw pickup
# 395          82       1              dodge rampage
# 396          82       1                ford ranger
# 397          82       1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model_year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
# 41 2019-12-04  Central  Hermann       Luis  Home Theater   94.00     500.000
# 42 2019-12-21  Central   Martha     Steven  Home Theater   28.00     500.000
# 43        NaT      NaN      NaN        NaN           NaN  278.00    1125.000
# 44        NaT      NaN      NaN        NaN           NaN   34.75     140.625
#
#      Sale_amt
# 0   113810.00
# 1    25000.00
# 2    43128.00
# 3     6075.00
# 4    67088.00
# 5    30000.00
# 6    89850.00
# 7   107820.00
# 8    38336.00
# 9    30000.00
# 10  107820.00
# 11   14500.00
# 12   40500.00
# 13   41930.00
# 14     250.00
# 15     936.00
# 16   14000.00
# 17   14400.00
# 18    3375.00
# 19    5616.00
# 20   80266.00
# 21    4329.00
# 22   23000.00
# 23   43500.00
# 24    2000.00
# 25    3500.00
# 26    2925.00
# 27   79068.00
# 28   21600.00
# 29   63494.00
# 30   40000.00
# 31     625.00
# 32    3627.00
# 33    3217.50
# 34    2457.00
# 35     375.00
# 36    8386.00
# 37   17100.00
# 38   28500.00
# 39   16772.00
# 40    5500.00
# 41   47000.00
# 42   14000.00
# 43   62550.00
# 44    7818.75

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43 entries, 0 to 42
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OrderDate   43 non-null     datetime64[ns]
#  1   Region      43 non-null     object
#  2   Manager     43 non-null     object
#  3   SalesMan    43 non-null     object
#  4   Item        43 non-null     object
#  5   Units       43 non-null     float64
#  6   Unit_price  43 non-null     float64
#  7   Sale_amt    43 non-null     float64
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 3.0+ KB

# %%
df.groupby('SalesMan').sum()[['Sale_amt']]
# Out:
# C:\Users\bldea\AppData\Local\Temp\ipykernel_10024\4143099978.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('SalesMan').sum()[['Sale_amt']]
#            Sale_amt
# SalesMan
# Alexander  236703.0
# David      140955.0
# Diana       36100.0
# John       124016.0
# Karen       48204.0
# Luis       206373.0
# Michael     66836.0
# Shelli      33698.0
# Sigal      125037.5
# Stephen     88063.0
# Steven     199690.0

# %%
df.groupby('SalesMan').sum().sort_values('Sale_amt')[['Sale_amt']]
# Out:
# C:\Users\bldea\AppData\Local\Temp\ipykernel_10024\2127898393.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('SalesMan').sum().sort_values('Sale_amt')[['Sale_amt']]
#            Sale_amt
# SalesMan
# Shelli      33698.0
# Diana       36100.0
# Karen       48204.0
# Michael     66836.0
# Stephen     88063.0
# John       124016.0
# Sigal      125037.5
# David      140955.0
# Steven     199690.0
# Luis       206373.0
# Alexander  236703.0

# %%
df.groupby(['Manager','SalesMan']).sum()[['Sale_amt']]
# Out:
# C:\Users\bldea\AppData\Local\Temp\ipykernel_10024\970159690.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['Manager','SalesMan']).sum()[['Sale_amt']]
#                    Sale_amt
# Manager SalesMan
# Douglas John       124016.0
#         Karen       48204.0
#         Michael     66836.0
# Hermann Luis       206373.0
#         Shelli      33698.0
#         Sigal      125037.5
# Martha  Alexander  236703.0
#         Diana       36100.0
#         Steven     199690.0
# Timothy David      140955.0
#         Stephen     88063.0

# %%
df.groupby(['Manager']).sum()[['Sale_amt']]
# Out:
# C:\Users\bldea\AppData\Local\Temp\ipykernel_10024\1518469702.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['Manager']).sum()[['Sale_amt']]
#          Sale_amt
# Manager
# Douglas  239056.0
# Hermann  365108.5
# Martha   472493.0
# Timothy  229018.0

# %%
df.groupby(['SalesMan','Item']).sum()[['Units']]
# Out:
# C:\Users\bldea\AppData\Local\Temp\ipykernel_10024\3504896505.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['SalesMan','Item']).sum()[['Units']]
#                         Units
# SalesMan  Item
# Alexander Cell Phone     64.0
#           Home Theater  124.0
#           Television    130.0
#           Video Games    78.0
# David     Cell Phone     27.0
#           Home Theater  126.0
#           Television     60.0
# Diana     Cell Phone     96.0
#           Home Theater   29.0
# John      Desk            2.0
#           Home Theater   87.0
#           Television     67.0
# Karen     Cell Phone     15.0
#           Home Theater   81.0
#           Video Games    74.0
# Luis      Home Theater  105.0
#           Television    126.0
#           Video Games    50.0
# Michael   Home Theater   57.0
#           Television     32.0
# Shelli    Desk            5.0
#           Home Theater   50.0
#           Video Games   138.0
# Sigal     Home Theater   28.0
#           Television     90.0
#           Video Games    55.0
# Stephen   Cell Phone     76.0
#           Desk            3.0
#           Home Theater    7.0
#           Television     56.0
# Steven    Home Theater   28.0
#           Television    155.0

# %%
df.groupby(['SalesMan','Item']).agg({'Units':sum, 'Sale_amt':sum})
# Out:
#                         Units  Sale_amt
# SalesMan  Item
# Alexander Cell Phone     64.0   14400.0
#           Home Theater  124.0   62000.0
#           Television    130.0  155740.0
#           Video Games    78.0    4563.0
# David     Cell Phone     27.0    6075.0
#           Home Theater  126.0   63000.0
#           Television     60.0   71880.0
# Diana     Cell Phone     96.0   21600.0
#           Home Theater   29.0   14500.0
# John      Desk            2.0     250.0
#           Home Theater   87.0   43500.0
#           Television     67.0   80266.0
# Karen     Cell Phone     15.0    3375.0
#           Home Theater   81.0   40500.0
#           Video Games    74.0    4329.0
# Luis      Home Theater  105.0   52500.0
#           Television    126.0  150948.0
#           Video Games    50.0    2925.0
# Michael   Home Theater   57.0   28500.0
#           Television     32.0   38336.0
# Shelli    Desk            5.0     625.0
#           Home Theater   50.0   25000.0
#           Video Games   138.0    8073.0
# Sigal     Home Theater   28.0   14000.0
#           Television     90.0  107820.0
#           Video Games    55.0    3217.5
# Stephen   Cell Phone     76.0   17100.0
#           Desk            3.0     375.0
#           Home Theater    7.0    3500.0
#           Television     56.0   67088.0
# Steven    Home Theater   28.0   14000.0
#           Television    155.0  185690.0

# %%
df.groupby('Region').sum()[['Sale_amt']]
# Out:
# C:\Users\bldea\AppData\Local\Temp\ipykernel_10024\249404901.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Region').sum()[['Sale_amt']]
#          Sale_amt
# Region
# Central  829769.5
# East     321007.0
# West     154899.0

# %%
df.groupby('Region').sum().sort_values('Sale_amt')[['Sale_amt']]
# Out:
# C:\Users\bldea\AppData\Local\Temp\ipykernel_10024\3965611221.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Region').sum().sort_values('Sale_amt')[['Sale_amt']]
#          Sale_amt
# Region
# West     154899.0
# East     321007.0
# Central  829769.5

# %%
import pandas as pd
df = pd.read_excel('dataset/SaleData.xlsx')
df
# Out:
#     OrderDate   Region  Manager   SalesMan          Item   Units  Unit_price  \
# 0  2018-01-06     East   Martha  Alexander    Television   95.00    1198.000
# 1  2018-01-23  Central  Hermann     Shelli  Home Theater   50.00     500.000
# 2  2018-02-09  Central  Hermann       Luis    Television   36.00    1198.000
# 3  2018-02-26  Central  Timothy      David    Cell Phone   27.00     225.000
# 4  2018-03-15     West  Timothy    Stephen    Television   56.00    1198.000
# 5  2018-04-01     East   Martha  Alexander  Home Theater   60.00     500.000
# 6  2018-04-18  Central   Martha     Steven    Television   75.00    1198.000
# 7  2018-05-05  Central  Hermann       Luis    Television   90.00    1198.000
# 8  2018-05-22     West  Douglas    Michael    Television   32.00    1198.000
# 29   63494.00
# 30   40000.00
# 31     625.00
# 32    3627.00
# 33    3217.50
# 34    2457.00
# 35     375.00
# 36    8386.00
# 37   17100.00
# 38   28500.00
# 39   16772.00
# 40    5500.00
# 41   47000.00
# 42   14000.00
# 43   62550.00
# 44    7818.75

# %%
df.isnull().sum()
# Out:
# OrderDate     2
# Region        2
# Manager       2
# SalesMan      2
# Item          2
# Units         0
# Unit_price    0
# Sale_amt      0
# dtype: int64

# %%
df.dropna(inplace=True)
df.head(20)
# Out:
#     OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price  \
# 0  2018-01-06     East   Martha  Alexander    Television   95.0      1198.0
# 1  2018-01-23  Central  Hermann     Shelli  Home Theater   50.0       500.0
# 2  2018-02-09  Central  Hermann       Luis    Television   36.0      1198.0
# 3  2018-02-26  Central  Timothy      David    Cell Phone   27.0       225.0
# 4  2018-03-15     West  Timothy    Stephen    Television   56.0      1198.0
# 5  2018-04-01     East   Martha  Alexander  Home Theater   60.0       500.0
# 6  2018-04-18  Central   Martha     Steven    Television   75.0      1198.0
# 7  2018-05-05  Central  Hermann       Luis    Television   90.0      1198.0
# 8  2018-05-22     West  Douglas    Michael    Television   32.0      1198.0
# 9  2018-06-08     East   Martha  Alexander  Home Theater   60.0       500.0
# 10 2018-06-25  Central  Hermann      Sigal    Television   90.0      1198.0
# 11 2018-07-12     East   Martha      Diana  Home Theater   29.0       500.0
# 12 2018-07-29     East  Douglas      Karen  Home Theater   81.0       500.0
# 13 2018-08-15     East   Martha  Alexander    Television   35.0      1198.0
# 14 2018-09-01  Central  Douglas       John          Desk    2.0       125.0
# 15 2018-09-18     East   Martha  Alexander   Video Games   16.0        58.5
# 16 2018-10-05  Central  Hermann      Sigal  Home Theater   28.0       500.0
# 17 2018-10-22     East   Martha  Alexander    Cell Phone   64.0       225.0
# 18 2018-11-08     East  Douglas      Karen    Cell Phone   15.0       225.0
# 19 2018-11-25  Central  Hermann     Shelli   Video Games   96.0        58.5
#
#     Sale_amt
# 0   113810.0
# 1    25000.0
# 2    43128.0
# 3     6075.0
# 4    67088.0
# 5    30000.0
# 6    89850.0
# 7   107820.0
# 8    38336.0
# 9    30000.0
# 10  107820.0
# 11   14500.0
# 12   40500.0
# 13   41930.0
# 14     250.0
# 15     936.0
# 16   14000.0
# 17   14400.0
# 18    3375.0
# 19    5616.0

# %%
df.groupby('SalesMan').sum()[['Sale_amt']]
# Out:
# C:\Users\bldea\AppData\Local\Temp\ipykernel_10024\4143099978.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('SalesMan').sum()[['Sale_amt']]
#            Sale_amt
# SalesMan
# Alexander  236703.0
# David      140955.0
# Diana       36100.0
# John       124016.0
# Karen       48204.0
# Luis       206373.0
# Michael     66836.0
# Shelli      33698.0
# Sigal      125037.5
# Stephen     88063.0
# Steven     199690.0

# %%
df.groupby('SalesMan').sum().sort_values('Sale_amt')[['Sale_amt']]
# Out:
# C:\Users\bldea\AppData\Local\Temp\ipykernel_10024\2127898393.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('SalesMan').sum().sort_values('Sale_amt')[['Sale_amt']]
#            Sale_amt
# SalesMan
# Shelli      33698.0
# Diana       36100.0
# Karen       48204.0
# Michael     66836.0
# Stephen     88063.0
# John       124016.0
# Sigal      125037.5
# David      140955.0
# Steven     199690.0
# Luis       206373.0
# Alexander  236703.0

# %%
df.groupby('SalesMan').sum().sort_values('Sale_amt', ascending=0)[['Sale_amt']]
# Out:
# C:\Users\bldea\AppData\Local\Temp\ipykernel_10024\3746177453.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('SalesMan').sum().sort_values('Sale_amt', ascending=0)[['Sale_amt']]
#            Sale_amt
# SalesMan
# Alexander  236703.0
# Luis       206373.0
# Steven     199690.0
# David      140955.0
# Sigal      125037.5
# John       124016.0
# Stephen     88063.0
# Michael     66836.0
# Karen       48204.0
# Diana       36100.0
# Shelli      33698.0

# %%
df.groupby(['Manager','SalesMan']).sum()[['Sale_amt']]
# Out:
# C:\Users\bldea\AppData\Local\Temp\ipykernel_10024\970159690.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['Manager','SalesMan']).sum()[['Sale_amt']]
#                    Sale_amt
# Manager SalesMan
# Douglas John       124016.0
#         Karen       48204.0
#         Michael     66836.0
# Hermann Luis       206373.0
#         Shelli      33698.0
#         Sigal      125037.5
# Martha  Alexander  236703.0
#         Diana       36100.0
#         Steven     199690.0
# Timothy David      140955.0
#         Stephen     88063.0

# %%
df.groupby('Manager').sum()[['Sale_amt']]
# Out:
# C:\Users\bldea\AppData\Local\Temp\ipykernel_10024\436343574.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Manager').sum()[['Sale_amt']]
#          Sale_amt
# Manager
# Douglas  239056.0
# Hermann  365108.5
# Martha   472493.0
# Timothy  229018.0

# %%
df.groupby(['SalesMan','Item']).sum()[['Units']]
# Out:
# C:\Users\bldea\AppData\Local\Temp\ipykernel_10024\3504896505.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['SalesMan','Item']).sum()[['Units']]
#                         Units
# SalesMan  Item
# Alexander Cell Phone     64.0
#           Home Theater  124.0
#           Television    130.0
#           Video Games    78.0
# David     Cell Phone     27.0
#           Home Theater  126.0
#           Television     60.0
# Diana     Cell Phone     96.0
#           Home Theater   29.0
# John      Desk            2.0
#           Home Theater   87.0
#           Television     67.0
# Karen     Cell Phone     15.0
#           Home Theater   81.0
#           Video Games    74.0
# Luis      Home Theater  105.0
#           Television    126.0
#           Video Games    50.0
# Michael   Home Theater   57.0
#           Television     32.0
# Shelli    Desk            5.0
#           Home Theater   50.0
#           Video Games   138.0
# Sigal     Home Theater   28.0
#           Television     90.0
#           Video Games    55.0
# Stephen   Cell Phone     76.0
#           Desk            3.0
#           Home Theater    7.0
#           Television     56.0
# Steven    Home Theater   28.0
#           Television    155.0

# %%
df.groupby(['SalesMan','Item']).sum()[['Units','Sale_amt']]
# Out:
# C:\Users\bldea\AppData\Local\Temp\ipykernel_10024\2129236953.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['SalesMan','Item']).sum()[['Units','Sale_amt']]
#                         Units  Sale_amt
# SalesMan  Item
# Alexander Cell Phone     64.0   14400.0
#           Home Theater  124.0   62000.0
#           Television    130.0  155740.0
#           Video Games    78.0    4563.0
# David     Cell Phone     27.0    6075.0
#           Home Theater  126.0   63000.0
#           Television     60.0   71880.0
# Diana     Cell Phone     96.0   21600.0
#           Home Theater   29.0   14500.0
# John      Desk            2.0     250.0
#           Home Theater   87.0   43500.0
#           Television     67.0   80266.0
# Karen     Cell Phone     15.0    3375.0
#           Home Theater   81.0   40500.0
#           Video Games    74.0    4329.0
# Luis      Home Theater  105.0   52500.0
#           Television    126.0  150948.0
#           Video Games    50.0    2925.0
# Michael   Home Theater   57.0   28500.0
#           Television     32.0   38336.0
# Shelli    Desk            5.0     625.0
#           Home Theater   50.0   25000.0
#           Video Games   138.0    8073.0
# Sigal     Home Theater   28.0   14000.0
#           Television     90.0  107820.0
#           Video Games    55.0    3217.5
# Stephen   Cell Phone     76.0   17100.0
#           Desk            3.0     375.0
#           Home Theater    7.0    3500.0
#           Television     56.0   67088.0
# Steven    Home Theater   28.0   14000.0
#           Television    155.0  185690.0

# %%
df.groupby(['SalesMan','Item']).agg({'Units':sum,'Sale_amt':sum})
# Out:
#                         Units  Sale_amt
# SalesMan  Item
# Alexander Cell Phone     64.0   14400.0
#           Home Theater  124.0   62000.0
#           Television    130.0  155740.0
#           Video Games    78.0    4563.0
# David     Cell Phone     27.0    6075.0
#           Home Theater  126.0   63000.0
#           Television     60.0   71880.0
# Diana     Cell Phone     96.0   21600.0
#           Home Theater   29.0   14500.0
# John      Desk            2.0     250.0
#           Home Theater   87.0   43500.0
#           Television     67.0   80266.0
# Karen     Cell Phone     15.0    3375.0
#           Home Theater   81.0   40500.0
#           Video Games    74.0    4329.0
# Luis      Home Theater  105.0   52500.0
#           Television    126.0  150948.0
#           Video Games    50.0    2925.0
# Michael   Home Theater   57.0   28500.0
#           Television     32.0   38336.0
# Shelli    Desk            5.0     625.0
#           Home Theater   50.0   25000.0
#           Video Games   138.0    8073.0
# Sigal     Home Theater   28.0   14000.0
#           Television     90.0  107820.0
#           Video Games    55.0    3217.5
# Stephen   Cell Phone     76.0   17100.0
#           Desk            3.0     375.0
#           Home Theater    7.0    3500.0
#           Television     56.0   67088.0
# Steven    Home Theater   28.0   14000.0
#           Television    155.0  185690.0

# %%
df.groupby('Region').sum()[['Sale_amt']]
# Out:
# C:\Users\bldea\AppData\Local\Temp\ipykernel_10024\249404901.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Region').sum()[['Sale_amt']]
#          Sale_amt
# Region
# Central  829769.5
# East     321007.0
# West     154899.0

# %%
df.groupby('Region').sum().sort_values('Sale_amt', ascending=0)[['Sale_amt']]
# Out:
# C:\Users\bldea\AppData\Local\Temp\ipykernel_10024\2991668511.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Region').sum().sort_values('Sale_amt', ascending=0)[['Sale_amt']]
#          Sale_amt
# Region
# Central  829769.5
# East     321007.0
# West     154899.0

# %%
df.groupby('Item').sum()[['Units']]
# Out:
# C:\Users\bldea\AppData\Local\Temp\ipykernel_10024\1092231605.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Item').sum()[['Units']]
#               Units
# Item
# Cell Phone    278.0
# Desk           10.0
# Home Theater  722.0
# Television    716.0
# Video Games   395.0

# %%
df.groupby('Item').sum()[['Units','Sale_amt']]
# Out:
# C:\Users\bldea\AppData\Local\Temp\ipykernel_10024\2377692021.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Item').sum()[['Units','Sale_amt']]
#               Units  Sale_amt
# Item
# Cell Phone    278.0   62550.0
# Desk           10.0    1250.0
# Home Theater  722.0  361000.0
# Television    716.0  857768.0
# Video Games   395.0   23107.5

# %%
df.groupby('Item').sum().sort_values('Sale_amt')[['Units','Sale_amt']]
# Out:
# C:\Users\bldea\AppData\Local\Temp\ipykernel_10024\3141452899.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Item').sum().sort_values('Sale_amt')[['Units','Sale_amt']]
#               Units  Sale_amt
# Item
# Desk           10.0    1250.0
# Video Games   395.0   23107.5
# Cell Phone    278.0   62550.0
# Home Theater  722.0  361000.0
# Television    716.0  857768.0

# %%
df.groupby('Item').sum().sort_values('Sale_amt',ascending=0)[['Units','Sale_amt']]
# Out:
# C:\Users\bldea\AppData\Local\Temp\ipykernel_10024\90979335.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('
# 41 2019-12-04  Central  Hermann       Luis  Home Theater   94.00     500.000
# 42 2019-12-21  Central   Martha     Steven  Home Theater   28.00     500.000
# 43        NaT      NaN      NaN        NaN           NaN  278.00    1125.000
# 44        NaT      NaN      NaN        NaN           NaN   34.75     140.625
#
#      Sale_amt
# 0   113810.00
# 1    25000.00
# 2    43128.00
# 3     6075.00
# 4    67088.00
# 5    30000.00
# 6    89850.00
# 7   107820.00
# 8    38336.00
# 9    30000.00
# 10  107820.00
# 11   14500.00
# 12   40500.00
# 13   41930.00
# 14     250.00
# 15     936.00
# 16   14000.00
# 17   14400.00
# 18    3375.00
# 19    5616.00
# 20   80266.00
# 21    4329.00
# 22   23000.00
# 23   43500.00
# 24    2000.00
# 25    3500.00
# 26    2925.00
# 27   79068.00
# 28   21600.00
# 29   63494.00
# 30   40000.00
# 31     625.00
# 32    3627.00
# 33    3217.50
# 34    2457.00
# 35     375.00
# 36    8386.00
# 37   17100.00
# 38   28500.00
# 39   16772.00
# 40    5500.00
# 41   47000.00
# 42   14000.00
# 43   62550.00
# 44    7818.75

# %%
pivot1 = pd.pivot_table(df, index = 'SalesMan', aggfunc=np.mean)
pivot1
# Out:
# C:\Users\bldea\AppData\Local\Temp\ipykernel_10024\1603653587.py:1: FutureWarning: The operation <function mean at 0x0000018585979300> failed on a column. If any error is raised, this will raise an exception in a future version of pandas. Drop these columns to avoid this warning.
#   pivot1 = pd.pivot_table(df, index = 'SalesMan', aggfunc=np.mean)
#                Sale_amt   Unit_price      Units
# SalesMan
# Alexander  29587.875000   529.750000  49.500000
# David      28191.000000   724.200000  42.600000
# Diana      18050.000000   362.500000  62.500000
# John       41338.666667   607.666667  52.000000
# Karen      16068.000000   261.166667  56.666667
# Luis       41274.600000   690.900000  56.200000
# Michael    33418.000000   849.000000  44.500000
# Shelli      8424.500000   185.500000  48.250000
# Sigal      41679.166667   585.500000  57.666667
# Stephen    22015.750000   512.000000  35.500000
# Steven     49922.500000  1023.500000  45.750000

# %%
import numpy as np
pivot1 = pd.pivot_table(df, index =['Manager','SalesMan'],values='Sale_amt')
pivot1
# Out:
#                        Sale_amt
# Manager SalesMan
# Douglas John       41338.666667
#         Karen      16068.000000
#         Michael    33418.000000
# Hermann Luis       41274.600000
#         Shelli      8424.500000
#         Sigal      41679.166667
# Martha  Alexander  29587.875000
#         Diana      18050.000000
#         Steven     49922.500000
# Timothy David      28191.000000
#         Stephen    22015.750000

# %%
import pandas as pd
from pandas import DataFrame
df = DataFrame(
                [
                    ['Aryan','Singh','Full-time','adminstration',2,20000],
                    ['Rohan','Agarawal','intern','Technical',3,5000],
                    ['Rjya','Shah','Full-time','adminstration',5,10000],
                    ['Yash','Bhatia','Part-time','Technical',7,10000],
                    ['Siddhant','Khanna','Full-time','Management',6,20000],
                ], columns=['First Name','Last name','Type','Department','YoE','Salary']
              )
df
# Out:
#   First Name Last name       Type     Department  YoE  Salary
# 0      Aryan     Singh  Full-time  adminstration    2   20000
# 1      Rohan  Agarawal     intern      Technical    3    5000
# 2       Rjya      Shah  Full-time  adminstration    5   10000
# 3       Yash    Bhatia  Part-time      Technical    7   10000
# 4   Siddhant    Khanna  Full-time     Management    6   20000

# %%
pd.pivot_table(df,index='Type')
# Out:
# C:\Users\bldea\AppData\Local\Temp\ipykernel_10024\3965019829.py:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   pd.pivot_table(df,index='Type')
#                  Salary       YoE
# Type
# Full-time  16666.666667  4.333333
# Part-time  10000.000000  7.000000
# intern      5000.000000  3.000000

# %%
pd.pivot_table(df[['Salary','Type']],index='Type')
# Out:
#                  Salary
# Type
# Full-time  16666.666667
# Part-time  10000.000000
# intern      5000.000000

# %%
marks_A = {'Chemistry': [67,90,66,32], 
        'Physics': [45,92,72,40],  
          }
marks_A_df = pd.DataFrame(marks_A, index = ['Subodh', 'Ram', 'Abdul', 'John'])
marks_B = {'Chemistry': [72,45,60,98], 
        'Physics': [78,34,72,95],  
          }
marks_B_df = pd.DataFrame(marks_B, index = ['Nandini', 'Zoya', 'Shivam', 'James'])
display(marks_A_df,marks_B_df)
# Out:
#         Chemistry  Physics
# Subodh         67       45
# Ram            90       92
# Abdul          66       72
# John           32       40
#          Chemistry  Physics
# Nandini         72       78
# Zoya            45       34
# Shivam          60       72
# James           98       95

# %%
pd.concat([marks_A_df,marks_B_df],sort=False)
# Out:
#          Chemistry  Physics
# Subodh          67       45
# Ram             90       92
# Abdul           66       72
# John            32       40
# Nandini         72       78
# Zoya            45       34
# Shivam          60       72
# James           98       95

# %%
df1 = pd.DataFrame({'employee': ['Jyoti', 'Sapna', 'Raj', 'Ramaswamy'],
                    'group': ['Accounting', 'Engineering', 'Engineering', 'HR']})
df2 = pd.DataFrame({'employee': ['Jyoti', 'Sapna', 'Raj', 'Ramaswamy'],
                    'hire_date': [2004, 2008, 2012, 2014]})
display(df1,df2)
# Out:
#     employee        group
# 0      Jyoti   Accounting
# 1      Sapna  Engineering
# 2        Raj  Engineering
# 3  Ramaswamy           HR
#     employee  hire_date
# 0      Jyoti       2004
# 1      Sapna       2008
# 2        Raj       2012
# 3  Ramaswamy       2014

# %%
pd.concat([df1,df2], sort = False)
# Out:
#     employee        group  hire_date
# 0      Jyoti   Accounting        NaN
# 1      Sapna  Engineering        NaN
# 2        Raj  Engineering        NaN
# 3  Ramaswamy           HR        NaN
# 0      Jyoti          NaN     2004.0
# 1      Sapna          NaN     2008.0
# 2        Raj          NaN     2012.0
# 3  Ramaswamy          NaN     2014.0

# %%
pd.merge(df1,df2)
# Out:
#     employee        group  hire_date
# 0      Jyoti   Accounting       2004
# 1      Sapna  Engineering       2008
# 2        Raj  Engineering       2012
# 3  Ramaswamy           HR       2014

# %%
import pandas as pd
df = pd.read_csv('dataset/auto-mpg.csv')
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# 1            70       1          buick skylark 320
# 2            70       1         plymouth satellite
# 3            70       1              amc rebel sst
# 4            70       1                ford torino
# ..          ...     ...                        ...
# 393          82       1            ford mustang gl
# 394          82       2                  vw pickup
# 395          82       1              dodge rampage
# 396          82       1                ford ranger
# 397          82       1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
pd.crosstab(df['model_year'], df['cylinders'])
# Out:
# cylinders   3   4  5   6   8
# model_year
# 70          0   7  0   4  18
# 71          0  13  0   8   7
# 72          1  14  0   0  13
# 73          1  11  0   8  20
# 74          0  15  0   7   5
# 75          0  12  0  12   6
# 76          0  15  0  10   9
# 77          1  14  0   5   8
# 78          0  17  1  12   6
# 79          0  12  1   6  10
# 80          1  25  1   2   0
# 81          0  21  0   7   1
# 82          0  28  0   3   0
